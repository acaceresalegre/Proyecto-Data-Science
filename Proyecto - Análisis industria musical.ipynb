# %% [markdown]
# Importación de librerias

# %%
#Librerias básicas
import pandas as pd
import numpy as np 

#Librerias de visualización
import matplotlib as mpl 
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Importación del dataset. Ranking de las canciones reproducidas en las principales plataformas
#
# El objetivo del trabajo es analizar el ranking de las canciones reproducidas en spotify y youtube.

# %%
dataset = pd.read_csv('cleaned_dataset.csv')

df = pd.DataFrame(dataset)

dataset.shape
# Out:
# (20594, 24)

# %%
dataset.columns
# Out:
# Index(['Artist', 'Track', 'Album', 'Album_type', 'Danceability', 'Energy',
#        'Loudness', 'Speechiness', 'Acousticness', 'Instrumentalness',
#        'Liveness', 'Valence', 'Tempo', 'Duration_min', 'Title', 'Channel',
#        'Views', 'Likes', 'Comments', 'Licensed', 'official_video', 'Stream',
#        'EnergyLiveness', 'most_playedon'],
#       dtype='object')

# %%
dataset.dtypes
# Out:
# Artist               object
# Track                object
# Album                object
# Album_type           object
# Danceability        float64
# Energy              float64
# Loudness            float64
# Speechiness         float64
# Acousticness        float64
# Instrumentalness    float64
# Liveness            float64
# Valence             float64
# Tempo               float64
# Duration_min        float64
# Title                object
# Channel              object
# Views               float64
# Likes               float64
# Comments            float64
# Licensed             object
# official_video       object
# Stream              float64
# EnergyLiveness      float64
# most_playedon        object
# dtype: object

# %%
dataset.sample(5)
# Out:
#                        Artist                                           Track  \
# 20213             Mc Paiva ZS                               Set Wesley Alemão
# 8295               Jelly Roll                                            Only
# 16011        The Chainsmokers                               Don't Let Me Down
# 18468           Billie Eilish                                           Bored
# 7764   Philharmonia Orchestra  Puccini: Gianni Schicchi: "O mio babbino caro"
#
#                    Album Album_type  Danceability  Energy  Loudness  \
# 20213  Set Wesley Alemão     single         0.689  0.5350    -8.537
# 8295     Addiction Kills      album         0.695  0.7450    -4.566
# 16011  Don't Let Me Down     single         0.532  0.8690    -5.094
# 18468              Bored     single         0.614  0.3180   -12.695
# 7764           La Divina      album         0.222  0.0977   -16.746
#
#        Speechiness  Acousticness  Instrumentalness  ...  \
# 20213       0.3570        0.3140           0.00000  ...
# 8295        0.0292        0.0124           0.00000  ...
# 16011       0.1720        0.1570           0.00508  ...
# 18468       0.0478        0.8960           0.00239  ...
# 7764        0.0396        0.9740           0.07110  ...
#
#                                                    Title  \
# 20213  SET WESLEY ALEMÃO - Lipi, Paulin da Capital, L...
# 8295       Jelly Roll - Only & Love The Heartless (Live)
# 16011  The Chainsmokers - Don't Let Me Down (Official...
# 18468                              Billie Eilish - Bored
# 7764     Puccini: Gianni Schicchi - "O mio babbino caro"
#
#                      Channel         Views       Likes  Comments Licensed  \
# 20213              Love Funk  5.880856e+07    725068.0   13521.0     True
# 8295              Jelly Roll  4.319451e+07    284650.0    6151.0    False
# 16011       ChainsmokersVEVO  1.918195e+09  12101095.0  284275.0     True
# 18468       BillieEilishVEVO  5.467207e+07   1089600.0   18839.0     True
# 7764   Renée Fleming - Topic  5.451830e+05      7073.0      28.0     True
#
#        official_video        Stream  EnergyLiveness most_playedon
# 20213            True  2.911819e+07        6.316411       Youtube
# 8295             True  4.228378e+07        8.632677       Youtube
# 16011            True  1.649896e+09        6.389706       Youtube
# 18468            True  6.728659e+08        4.000000       Spotify
# 7764             True  1.295300e+07        0.642763       Spotify
#
# [5 rows x 24 columns]
